# %% [markdown]
# # Brain Tumor MRI Classification
#
# EfficientNetB0 · 4 classes · transfer learning

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

from preprocessing import count_images
from config import DATA_DIR, CLASS_NAMES

print("Classes:", CLASS_NAMES)
print("Counts:", count_images(DATA_DIR))

# %% [markdown]
# ## Train

# %%
from train import train

# Optional: train(data_dir=r"D:\path\to\your\dataset")
model, hist_frozen, hist_ft = train()

# %% [markdown]
# ## Evaluate

# %%
from evaluate import evaluate

results = evaluate()

# %% [markdown]
# ## Predict one image

# %%
from inference import predict_pretty

# predict_pretty(r"path\to\mri.jpg")
